# %% [markdown]
# # Data Filtering

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import zipfile
from datetime import datetime
from glob import glob
from typing import Dict, List, Union

import boto3
import pandas as pd

# %%
PROJ_ROOT = os.path.join(os.pardir)
src_dir = os.path.join(PROJ_ROOT, "src")
sys.path.append(src_dir)

# %%
# %aimport file_utils
from file_utils import create_zip_file

# %aimport s3_utils
from s3_utils import (
    download_file_from_s3,
    extract_zip_file,
    upload_file_to_s3,
)

# %aimport text_filter_utils
from text_filter_utils import filter_files_per_hour

# %% [markdown]
# ## About

# %% [markdown]
# As part of this hourly data processing, we will now
# - filter out tweets with unwanted text in the tweet, where these texts include terms related to the following topics
#   - cryptocurrency (see the `crypto_terms` list below)
#   - video games (`video_game_terms`)
#   - religion (`religious_terms`)
#   - non-English words (`non_english_terms`)
#   - miscellaneous unwanted words (`misc_unwanted_terms`)
#   - inappropriate terms (profanity, etc. in `inappropriate_terms`)
# - only keep tweets that contain terms specific to the subject of this project and these terms are defined below in the following Python lists
#   - `tweet_search_terms`
#   - `case_sensitive_tweet_search_terms`
#   - `joined_tweet_search_terms`
#
#   which were built up using the sampled dataset
#   - created using `3-combine-data.ipynb` and then manually labeled
#   - filtered in `4_0_create_filter_data_list.ipynb` to pick up as many tweets as possible
#
# **Pre-Requisites**
# 1. In order to access data stored on Amazon S3, this data preparation notebook must be provided with the following environment variables
#    - `AWS_S3_BUCKET_NAME`

# %% [markdown]
# ## User Inputs

# %%
# raw data on S3
path_to_folder = "/datasets/twitter/kinesis-demo/"

# processed data
processed_data_dir = "../data/processed"  # (S3) "../data/processed" or (locally) "datasets/twitter/kinesis-demo/processed"
proc_zip_fname = "combined_data.zip"
filtered_zip_fname = "processed_data.zip"

# keep tweets with text containing terms
case_sensitive_tweet_search_terms = [
    # "NASA",  # picks up topics not related to the mission
    # "ESA",  # picks up topics not related to the mission
    # "CSA",  # picks up topics not related to the mission
    # "Kepler",  # picks up topics not related to the mission
]
tweet_search_terms = [
    # "aeronautics",
    "webb",
    # "goddard",  # picks up topics not related to the mission
    # "propulsion",  # picks up topics not related to the mission
    # "telescope",  # picks up topics not related to the mission
    # "exoplanet",  # picks up topics not related to the mission
    # 'launch',  # picks up topics not related to space exploration
    # 'astronomy',  # picks up random astronomers unrelated to the mission
    # 'astrophysics',  # picks up random astrophysicists unrelated to the mission
    # "laboratory",  # picks up random astronomers unrelated to the mission
    "jwst",
    "livestream",
    "congratulations",
    "congrats",
    "unfolding",
    "tightening",
    "tensioning",
    "sunshield",
    "sunshade",
    "l2",
    # "exploration",  # picks up topics not related to space exploration
    # " mission",  # picks up topics not related to space exploration
    # "spacecraft",  # picks up topics not related to the mission
]
joined_tweet_search_terms = [
    "james webb",
    # "space telescope",
    "webb space",
    "webb telescope",
    "mirror deploy",
    "space telescope",
    "telescope launch",
    "new telescope",
    "live coverage",
    "live stream",
    "heat shield",
    "primary mirror",
    "secondary mirror",
    # "jet propulsion lab",
    # "canadian space agency",
    # "european space agency",
    # "national aeronautics",
    # "shuttle launch",
    # "space shuttle",
    # "goddard space flight center",
    # "johnson space center",
    # "ames research center",
    # "marshall space flight center",
    # "glenn research center",
    # "ball aerospace",
    # "harris corporation",
    # "space telescope science institute",
    # "billochs",
    # "johndurning",
    # "johnmather",
    # "jonathangardner",
    # "northrop grumman",
    # "lockheed martin",
    # "stephen hawking",  # picks up topics not related to the mission
    # "dark matter",  # picks up topics not related to the mission
    # "dark energy",  # picks up topics not related to the mission
    # "hubble space",  # picks up topics not related to the mission
    # "hubble telescope",  # picks up topics not related to the mission
]
# remove tweets with text containing terms
crypto_terms = [
    "crypto",
    # "token",
    "koistarter",
    "daostarter",
    "decentralized",
    # "services",
    # "pancakeswap",
    # "eraxnft",
    # "browsing",
    # "kommunitas",
    # "hosting",
    # "internet",
    # "exipofficial",
    # "servers",
    # "wallet",
    # "liquidity",
    # "rewards",
    # "floki",
    # "10000000000000linkstelegram",
    "dogecoin",
    "czbinance",
    # "watch",
    "binance",
    "dogelonmars",
    "cryptocurrency",
    # "money",
    # "danheld",
    # "cybersecurity",
    "ethereum",
    "bitcrush",
    "vvsorigin",
]
video_games_terms = [
    # "gamejoin",
    "arcade",
    "dreamcast",
    "sega",
    "xbox",
    "wii",
    "ps4",
]
non_english_terms = [
    "webuye",
    "bungoma",
    "ethereum",
    "pay someone",
    "seungkwan",
    "woozi",
    "hoshi",
    "kasama",
    "nung",
    "lahat",
    "jinsoul",
    "brunisoul",
    "loona",
    "taas",
    "nung",
]
misc_unwanted_terms = [
    "nft",
    "volcano detected",
    "block-2",
    "tanzanite",
    "gemstonecarat",
    "popescu",
    "breeding",
    "nairobi",
    "pay someone",
    "homeworkpay",
    "homework",
    "photocards",
    "essay",
    # "hbomax",
]
religious_terms = [
    "scriptures",
    "methusealah",
    "testament",
    "yahweh",
    "god",
    "mullah",
    "allah",
    "clergy",
    "mercy",
    "morality",
    "muslims,",
    "hindus",
    "buddhist",
    "catholics",
    "christians",
    "atheist",
]
inappropriate_terms = [
    "prostitution",
    "musembe",
    "mo-greene",
    "running scared2012",
    "running scared 2012",
    "massacres",
    "eric ephriam chavez",
    "drugs",
    "bin laden",
    "saddam",
    "perished",
    "whore",
    "nasty",
    "nazist",
    "antifa",
    "proud boys",
]
min_num_words_tweet = 3

upload_to_s3 = True
cleanup_local_files = True

# columns for EDA
vcols = [
    "is_quote_status",
    "quote_count",
    "reply_count",
    # "retweet_count",
    "favorite_count",
    "favorited",
    "retweeted",
    "source_text",
    "user_followers",
    "user_friends",
    "user_favourites",
    "user_verified",
    "retweeted_tweet",
]

# %%
joined_tweet_search_terms_no_spaces = [
    t.replace(" ", "") for t in joined_tweet_search_terms
]
unwanted_partial_strings_list = (
    crypto_terms
    + religious_terms
    + inappropriate_terms
    + video_games_terms
    + misc_unwanted_terms
    + non_english_terms
)
dtypes_dict = {
    "id": pd.StringDtype(),
    "geo": pd.StringDtype(),
    "coordinates": pd.StringDtype(),
    "place": pd.StringDtype(),
    "contributors": pd.StringDtype(),  # pd.BooleanDtype(),
    "is_quote_status": pd.StringDtype(),  # pd.BooleanDtype(),
    "quote_count": pd.Int32Dtype(),
    "reply_count": pd.Int32Dtype(),
    "retweet_count": pd.Int32Dtype(),
    "favorite_count": pd.Int32Dtype(),
    "favorited": pd.StringDtype(),  # pd.BooleanDtype(),
    "retweeted": pd.StringDtype(),  # pd.BooleanDtype(),
    "source": pd.StringDtype(),
    "in_reply_to_user_id": pd.StringDtype(),
    "in_reply_to_screen_name": pd.StringDtype(),
    "source_text": pd.StringDtype(),
    "place_id": pd.StringDtype(),
    "place_url": pd.StringDtype(),
    "place_place_type": pd.StringDtype(),
    "place_name": pd.StringDtype(),
    "place_full_name": pd.StringDtype(),
    "place_country_code": pd.StringDtype(),
    "place_country": pd.StringDtype(),
    "place_bounding_box_type": pd.StringDtype(),
    "place_bounding_box_coordinates": pd.StringDtype(),
    "place_attributes": pd.StringDtype(),
    "coords_type": pd.StringDtype(),
    "coords_lon": pd.StringDtype(),
    "coords_lat": pd.StringDtype(),
    "geo_type": pd.StringDtype(),
    "geo_lon": pd.StringDtype(),
    "geo_lat": pd.StringDtype(),
    "user_name": pd.StringDtype(),
    "user_screen_name": pd.StringDtype(),
    "user_followers": pd.Int32Dtype(),
    "user_friends": pd.Int32Dtype(),
    "user_listed": pd.Int32Dtype(),
    "user_favourites": pd.Int32Dtype(),
    "user_statuses": pd.Int32Dtype(),
    "user_protected": pd.StringDtype(),  # pd.BooleanDtype(),
    "user_verified": pd.StringDtype(),  # pd.BooleanDtype(),
    "user_contributors_enabled": pd.StringDtype(),
    "user_location": pd.StringDtype(),
    "retweeted_tweet": pd.StringDtype(),
    "tweet_text_urls": pd.StringDtype(),
    "tweet_text_hashtags": pd.StringDtype(),
    "tweet_text_usernames": pd.StringDtype(),
    "num_urls_in_tweet_text": pd.Int32Dtype(),
    "num_users_in_tweet_text": pd.Int32Dtype(),
    "num_hashtags_in_tweet_text": pd.Int32Dtype(),
    "text": pd.StringDtype(),
    "contains_wanted_text": pd.BooleanDtype(),
    "contains_wanted_text_case_sensitive": pd.BooleanDtype(),
    "contains_multi_word_wanted_text": pd.BooleanDtype(),
    "contains_crypto_terms": pd.BooleanDtype(),
    "contains_religious_terms": pd.BooleanDtype(),
    "contains_inappropriate_terms": pd.BooleanDtype(),
    "contains_video_games_terms": pd.BooleanDtype(),
    "contains_misc_unwanted_terms": pd.BooleanDtype(),
    "contains_non_english_terms": pd.BooleanDtype(),
}

# %%
s3_bucket_name = os.getenv("AWS_S3_BUCKET_NAME", "")

try:
    session = boto3.Session(profile_name="default")
    s3_client = session.client("s3")
    aws_region = session.region_name
    print("Retrieved AWS credentials from ~/.ssh/aws file")
except Exception as e:
    if str(e) == "The config profile (default) could not be found":
        aws_region = os.getenv("AWS_REGION")
        s3_client = boto3.client("s3", region_name=aws_region)
        print("Retrieved AWS credentials from .env file")
# Out:
# Retrieved AWS credentials from .env file

# %% [markdown]
# ## Get Hourly Combined Data

# %%
# %%time
if not os.path.exists(os.path.join(processed_data_dir, proc_zip_fname)):
    download_file_from_s3(
        s3_client,
        s3_bucket_name,
        processed_data_dir,
        proc_zip_fname,
        aws_region,
        f"{path_to_folder[1:]}processed/",
    )
    extract_zip_file(os.path.join(processed_data_dir, proc_zip_fname), processed_data_dir)
combined_files = glob(f"{processed_data_dir}/*.parquet.gzip")
# Out:
# CPU times: user 393 µs, sys: 426 µs, total: 819 µs
# Wall time: 659 µs

# %% [markdown]
# ## Filter Data Per Hour

# %% [markdown]
# Run an ETL workflow to process hourly file objects in the S3 bucket
# - extract all hourly file objects into a single `pandas` `DataFrame`
# - process the hourly data
#   - exclude tweets that contain terms related to
#     - cryptocurrency
#     - video games
#     - non-English
#     - religious
#     - miscellaneous unwanted
#     - inappropriate
#
#     subjects
#   - include tweets that contain terms related to the subject of this project
#   - set appropriate datatypes
# - export the processed `DataFrame` to a `.parquet` file

# %%
# %%time
df_summary = filter_files_per_hour(
    combined_files,
    tweet_search_terms,
    case_sensitive_tweet_search_terms,
    joined_tweet_search_terms_no_spaces,
    crypto_terms,
    religious_terms,
    inappropriate_terms,
    video_games_terms,
    misc_unwanted_terms,
    non_english_terms,
    unwanted_partial_strings_list,
    min_num_words_tweet,
    dtypes_dict,
    processed_data_dir,
)
display(df_summary)
# Out:
# Filtering Tweets from combined data file 1/225 (2022010603.parquet.gzip)
# Starting time = 2022-10-25 23:55:29.498...
# Read 4,172 rows of data from parquet file 2022010603.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.240 | religious=1.294 | inappropriate=0.048 | video_games=0.048 | misc_unwanted=0.144 | non_english=0.336 | total unwanted=2.109
# Kept 108 tweets after filtering raw data with masks
# Kept 108 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:29.745 (0.247 seconds).
# Saving to parquet file filtered__2022010603.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 2/225 (2022010921.parquet.gzip)
# Starting time = 2022-10-25 23:55:29.752...
# Read 5,702 rows of data from parquet file 2022010921.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.456 | religious=1.491 | inappropriate=0.035 | video_games=0.035 | misc_unwanted=0.210 | non_english=0.018 | total unwanted=2.245
# Kept 339 tweets after filtering raw data with masks
# Kept 339 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:29.984 (0.232 seconds).
# Saving to parquet file filtered__2022010921.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 3/225 (2022010204.parquet.gzip)
# Starting time = 2022-10-25 23:55:29.992...
# Read 4,021 rows of data from parquet file 2022010204.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.119 | religious=0.224 | inappropriate=0.075 | video_games=0.075 | misc_unwanted=0.025 | non_english=0.075 | total unwanted=1.592
# Kept 165 tweets after filtering raw data with masks
# Kept 165 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:30.154 (0.163 seconds).
# Saving to parquet file filtered__2022010204.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 4/225 (2022010105.parquet.gzip)
# Starting time = 2022-10-25 23:55:30.162...
# Read 5,763 rows of data from parquet file 2022010105.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.729 | religious=0.087 | inappropriate=0.052 | video_games=0.000 | misc_unwanted=0.087 | non_english=0.104 | total unwanted=1.058
# Kept 203 tweets after filtering raw data with masks
# Kept 203 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:30.379 (0.217 seconds).
# Saving to parquet file filtered__2022010105.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 5/225 (2022010510.parquet.gzip)
# Starting time = 2022-10-25 23:55:30.387...
# Read 4,129 rows of data from parquet file 2022010510.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.187 | religious=0.412 | inappropriate=0.073 | video_games=0.024 | misc_unwanted=0.048 | non_english=0.048 | total unwanted=1.792
# Kept 141 tweets after filtering raw data with masks
# Kept 141 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:30.570 (0.183 seconds).
# Saving to parquet file filtered__2022010510.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 6/225 (2022010520.parquet.gzip)
# Starting time = 2022-10-25 23:55:30.576...
# Read 4,945 rows of data from parquet file 2022010520.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.627 | religious=0.566 | inappropriate=0.000 | video_games=0.000 | misc_unwanted=0.040 | non_english=0.000 | total unwanted=1.234
# Kept 303 tweets after filtering raw data with masks
# Kept 303 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:30.804 (0.227 seconds).
# Saving to parquet file filtered__2022010520.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 7/225 (2022010917.parquet.gzip)
# Starting time = 2022-10-25 23:55:30.811...
# Read 5,886 rows of data from parquet file 2022010917.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.425 | religious=2.446 | inappropriate=0.119 | video_games=0.017 | misc_unwanted=0.170 | non_english=0.034 | total unwanted=3.211
# Kept 582 tweets after filtering raw data with masks
# Kept 582 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:31.079 (0.268 seconds).
# Saving to parquet file filtered__2022010917.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 8/225 (2022010922.parquet.gzip)
# Starting time = 2022-10-25 23:55:31.088...
# Read 5,471 rows of data from parquet file 2022010922.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.512 | religious=1.005 | inappropriate=0.018 | video_games=0.073 | misc_unwanted=0.110 | non_english=0.000 | total unwanted=1.718
# Kept 240 tweets after filtering raw data with masks
# Kept 240 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:31.317 (0.230 seconds).
# Saving to parquet file filtered__2022010922.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 9/225 (2022010318.parquet.gzip)
# Starting time = 2022-10-25 23:55:31.324...
# Read 5,452 rows of data from parquet file 2022010318.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.678 | religious=0.422 | inappropriate=0.018 | video_games=0.073 | misc_unwanted=0.073 | non_english=0.055 | total unwanted=3.320
# Kept 118 tweets after filtering raw data with masks
# Kept 117 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:31.553 (0.229 seconds).
# Saving to parquet file filtered__2022010318.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 10/225 (2022010320.parquet.gzip)
# Starting time = 2022-10-25 23:55:31.559...
# Read 4,802 rows of data from parquet file 2022010320.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.354 | religious=0.312 | inappropriate=0.021 | video_games=0.146 | misc_unwanted=0.000 | non_english=0.000 | total unwanted=0.833
# Kept 139 tweets after filtering raw data with masks
# Kept 139 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:31.761 (0.202 seconds).
# Saving to parquet file filtered__2022010320.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 11/225 (2022010218.parquet.gzip)
# Starting time = 2022-10-25 23:55:31.768...
# Read 5,132 rows of data from parquet file 2022010218.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.143 | religious=0.487 | inappropriate=0.078 | video_games=0.312 | misc_unwanted=0.117 | non_english=0.624 | total unwanted=3.761
# Kept 93 tweets after filtering raw data with masks
# Kept 93 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:31.983 (0.215 seconds).
# Saving to parquet file filtered__2022010218.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 12/225 (2022010313.parquet.gzip)
# Starting time = 2022-10-25 23:55:31.989...
# Read 4,832 rows of data from parquet file 2022010313.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=7.740 | religious=0.248 | inappropriate=0.062 | video_games=0.103 | misc_unwanted=0.021 | non_english=0.124 | total unwanted=8.299
# Kept 67 tweets after filtering raw data with masks
# Kept 66 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:32.195 (0.205 seconds).
# Saving to parquet file filtered__2022010313.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 13/225 (2022010221.parquet.gzip)
# Starting time = 2022-10-25 23:55:32.201...
# Read 4,571 rows of data from parquet file 2022010221.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.875 | religious=0.525 | inappropriate=0.088 | video_games=0.088 | misc_unwanted=0.022 | non_english=0.459 | total unwanted=2.056
# Kept 158 tweets after filtering raw data with masks
# Kept 158 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:32.429 (0.228 seconds).
# Saving to parquet file filtered__2022010221.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 14/225 (2022010605.parquet.gzip)
# Starting time = 2022-10-25 23:55:32.436...
# Read 4,289 rows of data from parquet file 2022010605.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.093 | religious=1.282 | inappropriate=0.093 | video_games=0.047 | misc_unwanted=0.140 | non_english=0.070 | total unwanted=1.725
# Kept 114 tweets after filtering raw data with masks
# Kept 113 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:32.614 (0.178 seconds).
# Saving to parquet file filtered__2022010605.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 15/225 (2022010121.parquet.gzip)
# Starting time = 2022-10-25 23:55:32.621...
# Read 4,284 rows of data from parquet file 2022010121.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.607 | religious=0.350 | inappropriate=0.093 | video_games=0.093 | misc_unwanted=0.093 | non_english=0.000 | total unwanted=1.237
# Kept 139 tweets after filtering raw data with masks
# Kept 139 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:32.810 (0.189 seconds).
# Saving to parquet file filtered__2022010121.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 16/225 (2022010709.parquet.gzip)
# Starting time = 2022-10-25 23:55:32.816...
# Read 3,249 rows of data from parquet file 2022010709.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=5.879 | religious=1.016 | inappropriate=0.185 | video_games=0.062 | misc_unwanted=0.215 | non_english=0.277 | total unwanted=7.633
# Kept 102 tweets after filtering raw data with masks
# Kept 102 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:32.967 (0.151 seconds).
# Saving to parquet file filtered__2022010709.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 17/225 (2022010800.parquet.gzip)
# Starting time = 2022-10-25 23:55:32.973...
# Read 5,288 rows of data from parquet file 2022010800.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.246 | religious=0.321 | inappropriate=0.038 | video_games=0.019 | misc_unwanted=0.265 | non_english=0.019 | total unwanted=0.908
# Kept 204 tweets after filtering raw data with masks
# Kept 203 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:33.193 (0.220 seconds).
# Saving to parquet file filtered__2022010800.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 18/225 (2022010906.parquet.gzip)
# Starting time = 2022-10-25 23:55:33.200...
# Read 3,895 rows of data from parquet file 2022010906.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.411 | religious=0.282 | inappropriate=0.180 | video_games=0.103 | misc_unwanted=0.026 | non_english=0.128 | total unwanted=1.130
# Kept 447 tweets after filtering raw data with masks
# Kept 447 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:33.372 (0.172 seconds).
# Saving to parquet file filtered__2022010906.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 19/225 (2022010622.parquet.gzip)
# Starting time = 2022-10-25 23:55:33.381...
# Read 7,785 rows of data from parquet file 2022010622.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.103 | religious=0.244 | inappropriate=0.090 | video_games=0.026 | misc_unwanted=0.051 | non_english=0.000 | total unwanted=0.514
# Kept 795 tweets after filtering raw data with masks
# Kept 795 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:33.672 (0.291 seconds).
# Saving to parquet file filtered__2022010622.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 20/225 (2022010606.parquet.gzip)
# Starting time = 2022-10-25 23:55:33.681...
# Read 3,488 rows of data from parquet file 2022010606.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.917 | religious=1.290 | inappropriate=0.115 | video_games=0.029 | misc_unwanted=0.000 | non_english=0.115 | total unwanted=2.466
# Kept 158 tweets after filtering raw data with masks
# Kept 158 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:33.832 (0.151 seconds).
# Saving to parquet file filtered__2022010606.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 21/225 (2022010416.parquet.gzip)
# Starting time = 2022-10-25 23:55:33.839...
# Read 7,707 rows of data from parquet file 2022010416.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.155 | religious=0.208 | inappropriate=0.052 | video_games=0.026 | misc_unwanted=0.156 | non_english=0.234 | total unwanted=1.830
# Kept 382 tweets after filtering raw data with masks
# Kept 382 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:34.152 (0.313 seconds).
# Saving to parquet file filtered__2022010416.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 22/225 (2022010505.parquet.gzip)
# Starting time = 2022-10-25 23:55:34.159...
# Read 5,823 rows of data from parquet file 2022010505.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.447 | religious=0.086 | inappropriate=0.017 | video_games=0.017 | misc_unwanted=0.292 | non_english=1.391 | total unwanted=2.250
# Kept 222 tweets after filtering raw data with masks
# Kept 222 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:34.389 (0.230 seconds).
# Saving to parquet file filtered__2022010505.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 23/225 (2022010903.parquet.gzip)
# Starting time = 2022-10-25 23:55:34.397...
# Read 4,556 rows of data from parquet file 2022010903.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.154 | religious=0.241 | inappropriate=0.022 | video_games=0.088 | misc_unwanted=0.044 | non_english=0.044 | total unwanted=0.593
# Kept 659 tweets after filtering raw data with masks
# Kept 658 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:34.604 (0.207 seconds).
# Saving to parquet file filtered__2022010903.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 24/225 (2022010611.parquet.gzip)
# Starting time = 2022-10-25 23:55:34.615...
# Read 4,215 rows of data from parquet file 2022010611.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.237 | religious=0.712 | inappropriate=0.498 | video_games=0.047 | misc_unwanted=0.237 | non_english=0.356 | total unwanted=2.088
# Kept 121 tweets after filtering raw data with masks
# Kept 120 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:34.793 (0.178 seconds).
# Saving to parquet file filtered__2022010611.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 25/225 (2022010913.parquet.gzip)
# Starting time = 2022-10-25 23:55:34.801...
# Read 5,671 rows of data from parquet file 2022010913.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.670 | religious=0.141 | inappropriate=0.071 | video_games=0.035 | misc_unwanted=0.123 | non_english=0.882 | total unwanted=1.922
# Kept 584 tweets after filtering raw data with masks
# Kept 584 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:35.026 (0.225 seconds).
# Saving to parquet file filtered__2022010913.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 26/225 (2022010502.parquet.gzip)
# Starting time = 2022-10-25 23:55:35.035...
# Read 5,652 rows of data from parquet file 2022010502.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.195 | religious=0.301 | inappropriate=0.018 | video_games=0.035 | misc_unwanted=0.142 | non_english=0.071 | total unwanted=0.761
# Kept 411 tweets after filtering raw data with masks
# Kept 411 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:35.266 (0.231 seconds).
# Saving to parquet file filtered__2022010502.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 27/225 (2022010509.parquet.gzip)
# Starting time = 2022-10-25 23:55:35.274...
# Read 3,776 rows of data from parquet file 2022010509.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.257 | religious=0.265 | inappropriate=0.106 | video_games=0.079 | misc_unwanted=0.053 | non_english=0.106 | total unwanted=3.867
# Kept 169 tweets after filtering raw data with masks
# Kept 169 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:35.434 (0.161 seconds).
# Saving to parquet file filtered__2022010509.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 28/225 (2022010618.parquet.gzip)
# Starting time = 2022-10-25 23:55:35.442...
# Read 6,390 rows of data from parquet file 2022010618.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.156 | religious=0.360 | inappropriate=0.094 | video_games=0.078 | misc_unwanted=0.016 | non_english=0.000 | total unwanted=0.704
# Kept 184 tweets after filtering raw data with masks
# Kept 184 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:35.714 (0.272 seconds).
# Saving to parquet file filtered__2022010618.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 29/225 (2022010718.parquet.gzip)
# Starting time = 2022-10-25 23:55:35.721...
# Read 8,776 rows of data from parquet file 2022010718.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.060 | religious=0.399 | inappropriate=0.034 | video_games=0.023 | misc_unwanted=0.023 | non_english=0.034 | total unwanted=1.572
# Kept 279 tweets after filtering raw data with masks
# Kept 279 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:36.042 (0.321 seconds).
# Saving to parquet file filtered__2022010718.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 30/225 (2022010117.parquet.gzip)
# Starting time = 2022-10-25 23:55:36.050...
# Read 6,052 rows of data from parquet file 2022010117.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.711 | religious=0.182 | inappropriate=0.017 | video_games=0.050 | misc_unwanted=0.050 | non_english=0.033 | total unwanted=1.041
# Kept 210 tweets after filtering raw data with masks
# Kept 210 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:36.315 (0.266 seconds).
# Saving to parquet file filtered__2022010117.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 31/225 (2022010413.parquet.gzip)
# Starting time = 2022-10-25 23:55:36.322...
# Read 4,719 rows of data from parquet file 2022010413.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.695 | religious=0.381 | inappropriate=0.064 | video_games=0.085 | misc_unwanted=0.085 | non_english=0.191 | total unwanted=2.501
# Kept 183 tweets after filtering raw data with masks
# Kept 183 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:36.522 (0.199 seconds).
# Saving to parquet file filtered__2022010413.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 32/225 (2022010407.parquet.gzip)
# Starting time = 2022-10-25 23:55:36.530...
# Read 3,383 rows of data from parquet file 2022010407.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.739 | religious=0.177 | inappropriate=0.118 | video_games=0.030 | misc_unwanted=0.059 | non_english=0.325 | total unwanted=1.448
# Kept 146 tweets after filtering raw data with masks
# Kept 146 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:36.679 (0.149 seconds).
# Saving to parquet file filtered__2022010407.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 33/225 (2022010822.parquet.gzip)
# Starting time = 2022-10-25 23:55:36.685...
# Read 6,202 rows of data from parquet file 2022010822.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.661 | religious=0.403 | inappropriate=0.016 | video_games=0.016 | misc_unwanted=0.064 | non_english=0.000 | total unwanted=1.161
# Kept 1,113 tweets after filtering raw data with masks
# Kept 1,113 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:36.955 (0.269 seconds).
# Saving to parquet file filtered__2022010822.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 34/225 (2022010102.parquet.gzip)
# Starting time = 2022-10-25 23:55:36.965...
# Read 5,651 rows of data from parquet file 2022010102.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.035 | religious=0.159 | inappropriate=0.088 | video_games=0.000 | misc_unwanted=0.018 | non_english=0.000 | total unwanted=0.301
# Kept 425 tweets after filtering raw data with masks
# Kept 425 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:37.191 (0.225 seconds).
# Saving to parquet file filtered__2022010102.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 35/225 (2022010217.parquet.gzip)
# Starting time = 2022-10-25 23:55:37.198...
# Read 5,926 rows of data from parquet file 2022010217.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.232 | religious=0.489 | inappropriate=0.118 | video_games=0.371 | misc_unwanted=0.084 | non_english=0.742 | total unwanted=3.037
# Kept 99 tweets after filtering raw data with masks
# Kept 99 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:37.426 (0.228 seconds).
# Saving to parquet file filtered__2022010217.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 36/225 (2022010116.parquet.gzip)
# Starting time = 2022-10-25 23:55:37.433...
# Read 5,773 rows of data from parquet file 2022010116.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.975 | religious=0.104 | inappropriate=0.052 | video_games=0.069 | misc_unwanted=0.052 | non_english=0.087 | total unwanted=2.338
# Kept 205 tweets after filtering raw data with masks
# Kept 205 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:37.675 (0.242 seconds).
# Saving to parquet file filtered__2022010116.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 37/225 (2022010602.parquet.gzip)
# Starting time = 2022-10-25 23:55:37.682...
# Read 5,920 rows of data from parquet file 2022010602.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.051 | religious=1.030 | inappropriate=0.034 | video_games=0.068 | misc_unwanted=0.017 | non_english=0.017 | total unwanted=1.216
# Kept 177 tweets after filtering raw data with masks
# Kept 176 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:37.916 (0.234 seconds).
# Saving to parquet file filtered__2022010602.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 38/225 (2022010507.parquet.gzip)
# Starting time = 2022-10-25 23:55:37.923...
# Read 4,381 rows of data from parquet file 2022010507.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.735 | religious=0.388 | inappropriate=0.023 | video_games=0.000 | misc_unwanted=0.091 | non_english=0.068 | total unwanted=2.305
# Kept 156 tweets after filtering raw data with masks
# Kept 156 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:38.103 (0.179 seconds).
# Saving to parquet file filtered__2022010507.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 39/225 (2022010303.parquet.gzip)
# Starting time = 2022-10-25 23:55:38.110...
# Read 4,076 rows of data from parquet file 2022010303.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.466 | religious=0.270 | inappropriate=0.049 | video_games=0.049 | misc_unwanted=0.025 | non_english=0.466 | total unwanted=1.325
# Kept 87 tweets after filtering raw data with masks
# Kept 87 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:38.282 (0.171 seconds).
# Saving to parquet file filtered__2022010303.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 40/225 (2022010803.parquet.gzip)
# Starting time = 2022-10-25 23:55:38.288...
# Read 4,395 rows of data from parquet file 2022010803.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.341 | religious=0.228 | inappropriate=0.091 | video_games=0.023 | misc_unwanted=0.114 | non_english=0.068 | total unwanted=0.865
# Kept 160 tweets after filtering raw data with masks
# Kept 160 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:38.469 (0.181 seconds).
# Saving to parquet file filtered__2022010803.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 41/225 (2022010719.parquet.gzip)
# Starting time = 2022-10-25 23:55:38.476...
# Read 8,872 rows of data from parquet file 2022010719.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.642 | religious=0.214 | inappropriate=0.011 | video_games=0.011 | misc_unwanted=0.282 | non_english=0.000 | total unwanted=1.161
# Kept 994 tweets after filtering raw data with masks
# Kept 994 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:38.823 (0.347 seconds).
# Saving to parquet file filtered__2022010719.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 42/225 (2022010614.parquet.gzip)
# Starting time = 2022-10-25 23:55:38.834...
# Read 5,437 rows of data from parquet file 2022010614.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.037 | religious=0.644 | inappropriate=0.202 | video_games=0.037 | misc_unwanted=0.055 | non_english=0.147 | total unwanted=1.122
# Kept 148 tweets after filtering raw data with masks
# Kept 148 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:39.055 (0.221 seconds).
# Saving to parquet file filtered__2022010614.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 43/225 (2022010110.parquet.gzip)
# Starting time = 2022-10-25 23:55:39.061...
# Read 6,509 rows of data from parquet file 2022010110.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.874 | religious=0.031 | inappropriate=0.015 | video_games=0.046 | misc_unwanted=0.000 | non_english=0.031 | total unwanted=1.997
# Kept 124 tweets after filtering raw data with masks
# Kept 124 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:39.283 (0.222 seconds).
# Saving to parquet file filtered__2022010110.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 44/225 (2021123122.parquet.gzip)
# Starting time = 2022-10-25 23:55:39.323...
# Read 4,494 rows of data from parquet file 2021123122.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.357 | religious=0.289 | inappropriate=0.045 | video_games=0.178 | misc_unwanted=0.089 | non_english=0.022 | total unwanted=1.980
# Kept 278 tweets after filtering raw data with masks
# Kept 278 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:39.512 (0.189 seconds).
# Saving to parquet file filtered__2021123122.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 45/225 (2022010704.parquet.gzip)
# Starting time = 2022-10-25 23:55:39.519...
# Read 4,276 rows of data from parquet file 2022010704.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.164 | religious=0.164 | inappropriate=0.117 | video_games=0.070 | misc_unwanted=0.070 | non_english=0.164 | total unwanted=0.748
# Kept 134 tweets after filtering raw data with masks
# Kept 134 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:39.699 (0.180 seconds).
# Saving to parquet file filtered__2022010704.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 46/225 (2022010801.parquet.gzip)
# Starting time = 2022-10-25 23:55:39.706...
# Read 4,833 rows of data from parquet file 2022010801.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.435 | religious=0.517 | inappropriate=0.041 | video_games=0.000 | misc_unwanted=0.021 | non_english=0.041 | total unwanted=1.055
# Kept 208 tweets after filtering raw data with masks
# Kept 208 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:39.907 (0.202 seconds).
# Saving to parquet file filtered__2022010801.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 47/225 (2022010207.parquet.gzip)
# Starting time = 2022-10-25 23:55:39.916...
# Read 3,235 rows of data from parquet file 2022010207.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.526 | religious=0.185 | inappropriate=0.124 | video_games=0.062 | misc_unwanted=0.062 | non_english=0.433 | total unwanted=1.391
# Kept 73 tweets after filtering raw data with masks
# Kept 73 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:40.056 (0.141 seconds).
# Saving to parquet file filtered__2022010207.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 48/225 (2021123121.parquet.gzip)
# Starting time = 2022-10-25 23:55:40.063...
# Read 4,354 rows of data from parquet file 2021123121.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.413 | religious=0.184 | inappropriate=0.115 | video_games=0.184 | misc_unwanted=0.184 | non_english=0.023 | total unwanted=1.102
# Kept 366 tweets after filtering raw data with masks
# Kept 366 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:40.270 (0.207 seconds).
# Saving to parquet file filtered__2021123121.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 49/225 (2022010700.parquet.gzip)
# Starting time = 2022-10-25 23:55:40.279...
# Read 5,107 rows of data from parquet file 2022010700.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.255 | religious=0.215 | inappropriate=0.117 | video_games=0.078 | misc_unwanted=0.117 | non_english=0.137 | total unwanted=0.920
# Kept 165 tweets after filtering raw data with masks
# Kept 165 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:40.508 (0.229 seconds).
# Saving to parquet file filtered__2022010700.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 50/225 (2022010806.parquet.gzip)
# Starting time = 2022-10-25 23:55:40.515...
# Read 4,236 rows of data from parquet file 2022010806.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.275 | religious=0.496 | inappropriate=0.142 | video_games=0.024 | misc_unwanted=0.401 | non_english=0.047 | total unwanted=2.384
# Kept 179 tweets after filtering raw data with masks
# Kept 179 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:40.707 (0.192 seconds).
# Saving to parquet file filtered__2022010806.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 51/225 (2022010209.parquet.gzip)
# Starting time = 2022-10-25 23:55:40.715...
# Read 3,632 rows of data from parquet file 2022010209.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.936 | religious=0.275 | inappropriate=0.330 | video_games=0.000 | misc_unwanted=0.028 | non_english=0.330 | total unwanted=1.900
# Kept 76 tweets after filtering raw data with masks
# Kept 76 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:40.886 (0.171 seconds).
# Saving to parquet file filtered__2022010209.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 52/225 (2022010201.parquet.gzip)
# Starting time = 2022-10-25 23:55:40.892...
# Read 3,421 rows of data from parquet file 2022010201.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.351 | religious=0.292 | inappropriate=0.029 | video_games=0.117 | misc_unwanted=0.000 | non_english=0.438 | total unwanted=1.228
# Kept 92 tweets after filtering raw data with masks
# Kept 91 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:41.048 (0.155 seconds).
# Saving to parquet file filtered__2022010201.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 53/225 (2022010813.parquet.gzip)
# Starting time = 2022-10-25 23:55:41.054...
# Read 5,993 rows of data from parquet file 2022010813.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.835 | religious=0.300 | inappropriate=0.050 | video_games=0.050 | misc_unwanted=0.117 | non_english=0.133 | total unwanted=2.486
# Kept 702 tweets after filtering raw data with masks
# Kept 702 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:41.306 (0.253 seconds).
# Saving to parquet file filtered__2022010813.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 54/225 (2022010607.parquet.gzip)
# Starting time = 2022-10-25 23:55:41.316...
# Read 3,585 rows of data from parquet file 2022010607.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.474 | religious=1.339 | inappropriate=0.084 | video_games=0.000 | misc_unwanted=0.084 | non_english=0.028 | total unwanted=2.008
# Kept 102 tweets after filtering raw data with masks
# Kept 102 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:41.481 (0.165 seconds).
# Saving to parquet file filtered__2022010607.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 55/225 (2022010220.parquet.gzip)
# Starting time = 2022-10-25 23:55:41.489...
# Read 4,697 rows of data from parquet file 2022010220.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.724 | religious=0.341 | inappropriate=0.043 | video_games=0.192 | misc_unwanted=0.128 | non_english=0.852 | total unwanted=2.278
# Kept 128 tweets after filtering raw data with masks
# Kept 128 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:41.686 (0.197 seconds).
# Saving to parquet file filtered__2022010220.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 56/225 (2022010818.parquet.gzip)
# Starting time = 2022-10-25 23:55:41.695...
# Read 10,312 rows of data from parquet file 2022010818.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.270 | religious=0.407 | inappropriate=0.019 | video_games=0.019 | misc_unwanted=0.097 | non_english=0.000 | total unwanted=1.813
# Kept 2,483 tweets after filtering raw data with masks
# Kept 2,482 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:42.150 (0.455 seconds).
# Saving to parquet file filtered__2022010818.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 57/225 (2022010112.parquet.gzip)
# Starting time = 2022-10-25 23:55:42.167...
# Read 4,416 rows of data from parquet file 2022010112.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.649 | religious=0.159 | inappropriate=0.000 | video_games=0.000 | misc_unwanted=0.045 | non_english=0.045 | total unwanted=2.899
# Kept 136 tweets after filtering raw data with masks
# Kept 136 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:42.359 (0.193 seconds).
# Saving to parquet file filtered__2022010112.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 58/225 (2022010519.parquet.gzip)
# Starting time = 2022-10-25 23:55:42.367...
# Read 6,000 rows of data from parquet file 2022010519.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.033 | religious=0.833 | inappropriate=0.017 | video_games=0.050 | misc_unwanted=0.017 | non_english=0.017 | total unwanted=1.967
# Kept 267 tweets after filtering raw data with masks
# Kept 267 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:42.631 (0.264 seconds).
# Saving to parquet file filtered__2022010519.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 59/225 (2022010418.parquet.gzip)
# Starting time = 2022-10-25 23:55:42.638...
# Read 6,240 rows of data from parquet file 2022010418.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.929 | religious=0.769 | inappropriate=0.048 | video_games=0.000 | misc_unwanted=0.048 | non_english=0.000 | total unwanted=1.795
# Kept 515 tweets after filtering raw data with masks
# Kept 515 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:42.903 (0.265 seconds).
# Saving to parquet file filtered__2022010418.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 60/225 (2021123017.parquet.gzip)
# Starting time = 2022-10-25 23:55:42.912...
# Read 2,055 rows of data from parquet file 2021123017.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.438 | religious=0.146 | inappropriate=0.292 | video_games=0.097 | misc_unwanted=0.097 | non_english=0.146 | total unwanted=1.217
# Kept 123 tweets after filtering raw data with masks
# Kept 122 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:43.022 (0.111 seconds).
# Saving to parquet file filtered__2021123017.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 61/225 (2022010223.parquet.gzip)
# Starting time = 2022-10-25 23:55:43.029...
# Read 4,024 rows of data from parquet file 2022010223.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.224 | religious=0.348 | inappropriate=0.025 | video_games=0.174 | misc_unwanted=0.099 | non_english=0.348 | total unwanted=1.218
# Kept 102 tweets after filtering raw data with masks
# Kept 102 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:43.205 (0.176 seconds).
# Saving to parquet file filtered__2022010223.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 62/225 (2022010916.parquet.gzip)
# Starting time = 2022-10-25 23:55:43.211...
# Read 5,450 rows of data from parquet file 2022010916.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.752 | religious=1.009 | inappropriate=0.055 | video_games=0.055 | misc_unwanted=0.239 | non_english=0.165 | total unwanted=2.275
# Kept 466 tweets after filtering raw data with masks
# Kept 464 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:43.457 (0.245 seconds).
# Saving to parquet file filtered__2022010916.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 63/225 (2022010310.parquet.gzip)
# Starting time = 2022-10-25 23:55:43.465...
# Read 4,015 rows of data from parquet file 2022010310.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=4.533 | religious=0.224 | inappropriate=0.100 | video_games=0.025 | misc_unwanted=0.125 | non_english=0.498 | total unwanted=5.504
# Kept 64 tweets after filtering raw data with masks
# Kept 64 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:43.641 (0.176 seconds).
# Saving to parquet file filtered__2022010310.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 64/225 (2022010615.parquet.gzip)
# Starting time = 2022-10-25 23:55:43.649...
# Read 5,702 rows of data from parquet file 2022010615.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.333 | religious=0.807 | inappropriate=0.228 | video_games=0.000 | misc_unwanted=0.053 | non_english=0.228 | total unwanted=1.649
# Kept 178 tweets after filtering raw data with masks
# Kept 178 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:43.892 (0.243 seconds).
# Saving to parquet file filtered__2022010615.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 65/225 (2022010401.parquet.gzip)
# Starting time = 2022-10-25 23:55:43.899...
# Read 4,832 rows of data from parquet file 2022010401.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.145 | religious=0.269 | inappropriate=0.041 | video_games=0.145 | misc_unwanted=0.021 | non_english=0.021 | total unwanted=0.642
# Kept 95 tweets after filtering raw data with masks
# Kept 94 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:44.113 (0.214 seconds).
# Saving to parquet file filtered__2022010401.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 66/225 (2022010222.parquet.gzip)
# Starting time = 2022-10-25 23:55:44.120...
# Read 4,608 rows of data from parquet file 2022010222.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.130 | religious=0.347 | inappropriate=0.043 | video_games=0.022 | misc_unwanted=0.022 | non_english=0.477 | total unwanted=1.042
# Kept 126 tweets after filtering raw data with masks
# Kept 126 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:44.321 (0.201 seconds).
# Saving to parquet file filtered__2022010222.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 67/225 (2022010107.parquet.gzip)
# Starting time = 2022-10-25 23:55:44.329...
# Read 4,533 rows of data from parquet file 2022010107.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.552 | religious=0.132 | inappropriate=0.022 | video_games=0.022 | misc_unwanted=0.110 | non_english=0.022 | total unwanted=3.861
# Kept 181 tweets after filtering raw data with masks
# Kept 181 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:44.522 (0.193 seconds).
# Saving to parquet file filtered__2022010107.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 68/225 (2022010810.parquet.gzip)
# Starting time = 2022-10-25 23:55:44.530...
# Read 3,936 rows of data from parquet file 2022010810.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.388 | religious=0.457 | inappropriate=0.076 | video_games=0.076 | misc_unwanted=0.305 | non_english=0.051 | total unwanted=3.354
# Kept 140 tweets after filtering raw data with masks
# Kept 140 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:55:44.712 (0.182 seconds).
# Saving to parquet file filtered__2022010810.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 69/225 (2022010421.parquet.gzip)
# Starting time = 2022-10-25 23:55:44.719...
# Read 4,755 rows of data from parquet file 2022010421.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.883 | religious=0.673 | inappropriate=0.021 | video_games=0.084 | misc_unwanted=0.042 | non_english=0.042 | total unwanted=1.746
# ...
# Done.
#
# Filtering Tweets from combined data file 205/225 (2022010503.parquet.gzip)
# Starting time = 2022-10-25 23:56:16.543...
# Read 6,370 rows of data from parquet file 2022010503.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.455 | religious=0.204 | inappropriate=0.016 | video_games=0.031 | misc_unwanted=0.031 | non_english=0.078 | total unwanted=0.816
# Kept 254 tweets after filtering raw data with masks
# Kept 254 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:16.805 (0.262 seconds).
# Saving to parquet file filtered__2022010503.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 206/225 (2022010902.parquet.gzip)
# Starting time = 2022-10-25 23:56:16.812...
# Read 4,804 rows of data from parquet file 2022010902.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.187 | religious=0.271 | inappropriate=0.021 | video_games=0.125 | misc_unwanted=0.104 | non_english=0.062 | total unwanted=0.770
# Kept 726 tweets after filtering raw data with masks
# Kept 726 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:17.042 (0.230 seconds).
# Saving to parquet file filtered__2022010902.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 207/225 (2022010309.parquet.gzip)
# Starting time = 2022-10-25 23:56:17.052...
# Read 3,716 rows of data from parquet file 2022010309.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.457 | religious=0.377 | inappropriate=0.054 | video_games=0.081 | misc_unwanted=0.027 | non_english=0.269 | total unwanted=1.265
# Kept 74 tweets after filtering raw data with masks
# Kept 74 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:17.242 (0.190 seconds).
# Saving to parquet file filtered__2022010309.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 208/225 (2022010104.parquet.gzip)
# Starting time = 2022-10-25 23:56:17.249...
# Read 5,709 rows of data from parquet file 2022010104.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.490 | religious=0.193 | inappropriate=0.018 | video_games=0.018 | misc_unwanted=0.070 | non_english=0.088 | total unwanted=0.876
# Kept 337 tweets after filtering raw data with masks
# Kept 337 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:17.526 (0.277 seconds).
# Saving to parquet file filtered__2022010104.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 209/225 (2022010908.parquet.gzip)
# Starting time = 2022-10-25 23:56:17.534...
# Read 3,923 rows of data from parquet file 2022010908.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.433 | religious=0.484 | inappropriate=0.076 | video_games=0.051 | misc_unwanted=0.025 | non_english=0.127 | total unwanted=1.198
# Kept 568 tweets after filtering raw data with masks
# Kept 568 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:17.713 (0.179 seconds).
# Saving to parquet file filtered__2022010908.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 210/225 (2022010911.parquet.gzip)
# Starting time = 2022-10-25 23:56:17.722...
# Read 3,643 rows of data from parquet file 2022010911.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.180 | religious=1.016 | inappropriate=0.027 | video_games=0.027 | misc_unwanted=0.055 | non_english=0.055 | total unwanted=2.361
# Kept 430 tweets after filtering raw data with masks
# Kept 430 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:17.893 (0.171 seconds).
# Saving to parquet file filtered__2022010911.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 211/225 (2021123119.parquet.gzip)
# Starting time = 2022-10-25 23:56:17.901...
# Read 4,434 rows of data from parquet file 2021123119.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=4.285 | religious=0.293 | inappropriate=0.045 | video_games=0.045 | misc_unwanted=0.135 | non_english=0.023 | total unwanted=4.826
# Kept 103 tweets after filtering raw data with masks
# Kept 103 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:18.085 (0.183 seconds).
# Saving to parquet file filtered__2021123119.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 212/225 (2022010410.parquet.gzip)
# Starting time = 2022-10-25 23:56:18.093...
# Read 3,498 rows of data from parquet file 2022010410.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.715 | religious=0.200 | inappropriate=0.143 | video_games=0.000 | misc_unwanted=0.000 | non_english=0.372 | total unwanted=2.430
# Kept 132 tweets after filtering raw data with masks
# Kept 132 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:18.248 (0.155 seconds).
# Saving to parquet file filtered__2022010410.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 213/225 (2022010712.parquet.gzip)
# Starting time = 2022-10-25 23:56:18.255...
# Read 3,843 rows of data from parquet file 2022010712.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.390 | religious=0.286 | inappropriate=0.026 | video_games=0.026 | misc_unwanted=0.000 | non_english=0.468 | total unwanted=1.197
# Kept 125 tweets after filtering raw data with masks
# Kept 125 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:18.425 (0.170 seconds).
# Saving to parquet file filtered__2022010712.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 214/225 (2022010500.parquet.gzip)
# Starting time = 2022-10-25 23:56:18.431...
# Read 4,406 rows of data from parquet file 2022010500.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.159 | religious=0.272 | inappropriate=0.113 | video_games=0.023 | misc_unwanted=0.023 | non_english=0.045 | total unwanted=0.635
# Kept 390 tweets after filtering raw data with masks
# Kept 390 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:18.631 (0.200 seconds).
# Saving to parquet file filtered__2022010500.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 215/225 (2022010522.parquet.gzip)
# Starting time = 2022-10-25 23:56:18.641...
# Read 6,089 rows of data from parquet file 2022010522.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.213 | religious=0.345 | inappropriate=0.066 | video_games=0.115 | misc_unwanted=0.066 | non_english=0.000 | total unwanted=0.805
# Kept 180 tweets after filtering raw data with masks
# Kept 180 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:18.903 (0.262 seconds).
# Saving to parquet file filtered__2022010522.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 216/225 (2022010122.parquet.gzip)
# Starting time = 2022-10-25 23:56:18.911...
# Read 3,950 rows of data from parquet file 2022010122.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.127 | religious=0.354 | inappropriate=0.051 | video_games=0.076 | misc_unwanted=0.000 | non_english=0.076 | total unwanted=0.684
# Kept 152 tweets after filtering raw data with masks
# Kept 152 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:19.113 (0.202 seconds).
# Saving to parquet file filtered__2022010122.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 217/225 (2022010915.parquet.gzip)
# Starting time = 2022-10-25 23:56:19.120...
# Read 5,586 rows of data from parquet file 2022010915.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.591 | religious=0.698 | inappropriate=0.072 | video_games=0.000 | misc_unwanted=0.233 | non_english=0.072 | total unwanted=1.665
# Kept 555 tweets after filtering raw data with masks
# Kept 555 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:19.385 (0.265 seconds).
# Saving to parquet file filtered__2022010915.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 218/225 (2022010414.parquet.gzip)
# Starting time = 2022-10-25 23:56:19.395...
# Read 6,173 rows of data from parquet file 2022010414.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.907 | religious=0.113 | inappropriate=0.065 | video_games=0.032 | misc_unwanted=0.049 | non_english=0.146 | total unwanted=1.312
# Kept 647 tweets after filtering raw data with masks
# Kept 647 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:19.693 (0.298 seconds).
# Saving to parquet file filtered__2022010414.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 219/225 (2022010408.parquet.gzip)
# Starting time = 2022-10-25 23:56:19.702...
# Read 3,262 rows of data from parquet file 2022010408.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.931 | religious=0.521 | inappropriate=0.031 | video_games=0.031 | misc_unwanted=0.123 | non_english=0.337 | total unwanted=2.974
# Kept 186 tweets after filtering raw data with masks
# Kept 186 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:19.853 (0.151 seconds).
# Saving to parquet file filtered__2022010408.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 220/225 (2022010805.parquet.gzip)
# Starting time = 2022-10-25 23:56:19.861...
# Read 5,194 rows of data from parquet file 2022010805.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.154 | religious=0.193 | inappropriate=0.096 | video_games=0.039 | misc_unwanted=0.327 | non_english=0.077 | total unwanted=0.886
# Kept 177 tweets after filtering raw data with masks
# Kept 177 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:20.065 (0.204 seconds).
# Saving to parquet file filtered__2022010805.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 221/225 (2022010623.parquet.gzip)
# Starting time = 2022-10-25 23:56:20.073...
# Read 5,705 rows of data from parquet file 2022010623.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.193 | religious=0.228 | inappropriate=0.070 | video_games=0.088 | misc_unwanted=0.088 | non_english=0.035 | total unwanted=0.701
# Kept 305 tweets after filtering raw data with masks
# Kept 305 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:20.318 (0.244 seconds).
# Saving to parquet file filtered__2022010623.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 222/225 (2022010613.parquet.gzip)
# Starting time = 2022-10-25 23:56:20.326...
# Read 4,431 rows of data from parquet file 2022010613.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.429 | religious=0.519 | inappropriate=0.203 | video_games=0.000 | misc_unwanted=0.068 | non_english=0.135 | total unwanted=1.354
# Kept 168 tweets after filtering raw data with masks
# Kept 168 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:20.541 (0.215 seconds).
# Saving to parquet file filtered__2022010613.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 223/225 (2022010722.parquet.gzip)
# Starting time = 2022-10-25 23:56:20.548...
# Read 6,534 rows of data from parquet file 2022010722.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.306 | religious=0.888 | inappropriate=0.015 | video_games=0.046 | misc_unwanted=0.061 | non_english=0.031 | total unwanted=1.347
# Kept 337 tweets after filtering raw data with masks
# Kept 337 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:20.829 (0.280 seconds).
# Saving to parquet file filtered__2022010722.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 224/225 (2021123118.parquet.gzip)
# Starting time = 2022-10-25 23:56:20.836...
# Read 3,555 rows of data from parquet file 2021123118.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.657 | religious=0.281 | inappropriate=0.056 | video_games=0.197 | misc_unwanted=0.056 | non_english=0.084 | total unwanted=4.332
# Kept 113 tweets after filtering raw data with masks
# Kept 113 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:20.992 (0.156 seconds).
# Saving to parquet file filtered__2021123118.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 225/225 (2022010617.parquet.gzip)
# Starting time = 2022-10-25 23:56:20.999...
# Read 7,336 rows of data from parquet file 2022010617.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.136 | religious=0.368 | inappropriate=0.177 | video_games=0.041 | misc_unwanted=0.027 | non_english=0.055 | total unwanted=0.804
# Kept 232 tweets after filtering raw data with masks
# Kept 232 tweets with more than approximately 3 words per tweet
# Done filtering at 2022-10-25 23:56:21.329 (0.329 seconds).
# Saving to parquet file filtered__2022010617.parquet.gzip...
# Done.
#
# Combined data contained 1,155,499 rows
# Filtered data contains 65,639 rows
#                                       filename  num_rows_combined  \
# 0    ../data/processed/2022010603.parquet.gzip               4172
# 1    ../data/processed/2022010921.parquet.gzip               5702
# 2    ../data/processed/2022010204.parquet.gzip               4021
# 3    ../data/processed/2022010105.parquet.gzip               5763
# 4    ../data/processed/2022010510.parquet.gzip               4129
# ..                                         ...                ...
# 220  ../data/processed/2022010623.parquet.gzip               5705
# 221  ../data/processed/2022010613.parquet.gzip               4431
# 222  ../data/processed/2022010722.parquet.gzip               6534
# 223  ../data/processed/2021123118.parquet.gzip               3555
# 224  ../data/processed/2022010617.parquet.gzip               7336
#
#      num_rows_filtered
# 0                  108
# 1                  339
# 2                  165
# 3                  203
# 4                  141
# ..                 ...
# 220                305
# 221                168
# 222                337
# 223                113
# 224                232
#
# [225 rows x 3 columns]
# CPU times: user 53 s, sys: 877 ms, total: 53.9 s
# Wall time: 51.9 s

# %% [markdown]
# **Notes**
# 1. Like the previous notebook, this ETL workflow will also give a single `.parquet` file for every hour of every day on which tweets were streamed. Since the number of hourly tweets for this subject are small enough to fit into memory, it is possible to use `pandas` (in-memory) for filtering the hourly data.

# %% [markdown]
# ## Compress to `.zip` and Upload to S3

# %% [markdown]
# All `.parquet` files are now
# - combined into a single `.zip` file with a `filtered__` prefix in the filename, which is then
#   - uploaded to the `datasets/twitter/kinesis-demo/processed` prefix in the S3 bucket
#   - deleted locally
# - deleted locally

# %%
# %%time
if upload_to_s3:
    # zip all processed data files, upload to S3, delete local files
    # create zip of all .parquet.gzip processed data files
    curr_dir = os.getcwd()
    create_zip_file("filtered__*.parquet.gzip", processed_data_dir, filtered_zip_fname)
    # upload zip file to S3 bucket
    try:
        assert os.getcwd() == curr_dir
        upload_file_to_s3(
            aws_region,
            processed_data_dir,
            filtered_zip_fname,
            s3_bucket_name,
            f"{path_to_folder[1:-1]}/processed/{filtered_zip_fname}",
        )
        print("\nUploaded filtered zipped file to S3 bucket")
    except AssertionError as e:
        print(
            f"\n{str(e)}: Incorrect working directory. "
            "Did not upload filtered zipped file to S3 bucket."
        )

if cleanup_local_files:
    # 1. delete local combined parquet files and locally exported processed parquet files
    list(
        map(
            os.remove,
            glob(f"{processed_data_dir}/*.parquet.gzip"),
        )
    )
    print("Deleted local .parquet.gzip files with combined and filtered data.")

    # 3. delete local processed zip file
    os.remove(os.path.join(processed_data_dir, proc_zip_fname))
    print("Deleted local .zip file created from all combined data files.")

    # 4. delete local filtered zip file
    os.remove(os.path.join(processed_data_dir, filtered_zip_fname))
    print("Deleted local .zip file created from all filtered data files.")
# Out:
# Created zip file at ../data/processed/processed_data.zip
#
# Uploaded filtered zipped file to S3 bucket
# Deleted local .parquet.gzip files with combined and filtered data.
# Deleted local .zip file created from all combined data files.
# Deleted local .zip file created from all filtered data files.
# CPU times: user 631 ms, sys: 60.5 ms, total: 691 ms
# Wall time: 1.78 s

# %% [markdown]
# ---

# %% [markdown]
# <span style="float:left;">
#     <a href="./3-combine-data/notebooks/3_combine_data.ipynb"><< 3 - Combine Hourly Streamed Tweets</a>
# </span>
#
# <span style="float:right;">
#     <a href="./5-process-data/notebooks/5_process_data.ipynb">5 - Data Processing >></a>
# </span>
