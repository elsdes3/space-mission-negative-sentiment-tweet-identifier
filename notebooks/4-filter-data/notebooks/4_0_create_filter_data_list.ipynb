# %% [markdown]
# # Building Up List of Suitable Tweet Search Terms

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
from glob import glob

import pandas as pd

# %% [markdown]
# ## About

# %% [markdown]
# This notebook performs the following
# 1. loads the sampled data that was
#    - created in `/3-combine-data/notebooks/3-combine-data.ipynb`
#    - manually labeled with the subject of the tweet
# 2. filters the data to capture the (manually labeled) wanted subjects
# 3. builds up a list of search terms that captures as many tweets in the filtered data (i.e. as many tweets belonging to a wanted subject)

# %% [markdown]
# ## User Inputs

# %%
processed_data_dir = "../data/processed"

cols_to_use = ["text", "subject"]

wanted_list = [
    "webb",
    "jwst",
    "webb space",
    "webb telescope",
    "mirror deploy",
    "space telescope",
    "telescope launch",
    "new telescope",
    "live coverage",
    "live stream",
    "livestream",
    "congratulations",
    "congrats",
    "unfolding",
    "tightening",
    "tensioning",
    "sunshield",
    "sunshade",
    "l2",
    "heat shield",
    "primary mirror",
    "secondary mirror",
]
wanted_subject_strs = ["Jwst-mission", "Jwst-facts"]

# %%
wanted_str = "|".join(wanted_list)

# %% [markdown]
# ## Get Data

# %% [markdown]
# Load annotated data

# %%
# %%time
df = pd.concat(
    [
        pd.read_excel(f, usecols=cols_to_use).dropna(subset=["subject"])
        for f in glob(f"{processed_data_dir}/*.xlsx")
    ],
    axis=0,
    ignore_index=True,
)
with pd.option_context('display.max_colwidth', None):
    display(df.head())
df.info()
# Out:
#                                                                                                                                                                   text  \
# 0                                                                                     Q: How do you send a payload to the James Webb Space Telescope?A: ${jwst:ldap://
# 1                                                                               Why NASA's James Webb telescope Twitter account blocked other NASA Twitter accounts  [
# 2  With Webb’s Mid-Booms Extended, Sunshield Takes Shape – James Webb Space Telescope 　Sunshield STARBOARD Mid-BoomThe Right/Starboard (-J2) Sunshield Boom Deployment
# 3                                                                                                            The first image from the new James Webb telescope is in!
# 4                                                                                             Still can't believe we did the space shuttle. Nation of absolute madmen.
#
#           subject
# 0    Jwst-mission
# 1      Jwst-facts
# 2    Jwst-mission
# 3    Jwst-mission
# 4  Other-missions
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1348 entries, 0 to 1347
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   text     1348 non-null   object
#  1   subject  1348 non-null   object
# dtypes: object(2)
# memory usage: 21.2+ KB
# CPU times: user 209 ms, sys: 31.9 ms, total: 241 ms
# Wall time: 343 ms

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Show distribution of tweet subjects in annotated data

# %%
df["subject"].value_counts().rename("count").to_frame().merge(
    (100 * df["subject"].value_counts(normalize=True).rename("fraction").to_frame()),
    left_index=True,
    right_index=True,
    how="left",
).rename_axis("subject").reset_index()
# Out:
#           subject  count   fraction
# 0            misc    370  27.448071
# 1    Jwst-mission    287  21.290801
# 2  Other-missions    220  16.320475
# 3    Nasa-science    127   9.421365
# 4          images    112   8.308605
# 5      Jwst-facts     97   7.195846
# 6    Nasa-careers     45   3.338279
# 7    Nasa-funding     40   2.967359
# 8      telescopes     26   1.928783
# 9    Rover-images     24   1.780415

# %% [markdown]
# **Notes**
# 1. During manual labeling of the tweets, those belonging to an unrelated subject do not contain *Jwst* in the subject name.
# 2. Some tweets related to *telescopes* might involve discussion related to the current project, but this was not always found to be the case. Additionally, tweets belonging to this subject make up less than 5% of all manually labeled tweets and so we will proceed to discard these from further use.

# %% [markdown]
# **Observations**
# 1. The subjects required for this project are
#    - *Jwst-mission*
#    - *Jwst-facts*
#
#    so we will focus on building a list of search terms that only efficiently filters tweets belonging to those in these two subjects. This list will not be suitable for use with other subjects but this is acceptable since this project is focused on the above two subjects only.

# %% [markdown]
# ## Filter Data

# %% [markdown]
# Filter tweets to get required subjects

# %%
df_subjects = df.query("subject.isin(@wanted_subject_strs)")

# %% [markdown]
# From filtered data, get tweets containing wanted
# - standalone, or
# - joined
#
# terms in the text of the tweet

# %%
df_unexpected = df_subjects.query("~text.str.lower().str.contains(@wanted_str)")

# %% [markdown]
# Show the leftover tweets that are not captured by the filter term list defined above (`wanted_list`)

# %%
print(
    f"Found {len(df_unexpected):,} leftover tweets "
    f"({100*len(df_unexpected)/len(df_subjects):.3f}%) "
    f"out of {len(df_subjects):,} candidate tweets matching the wanted subjects"
)
with pd.option_context("display.max_rows", None, "display.max_colwidth", None):
    display(df_unexpected)
# Out:
# Found 30 leftover tweets (7.812%) out of 384 candidate tweets matching the wanted subjects
#                                                                                                                                                                                                                                                                                           text  \
# 113                                                                                                                                                                                                          Can’t wait to see this thing in action: NASA’s finest moment since saving Hubble.
# 146                         I am not with NASA so this is just my opinion: It all depends where the tear would be, I imagine that if it is towards the outside of the shield( away from the center) its ok, also, remember that the main sensors are actively cooled (new tech refrigeration)!
# 159                                                                                                                                                                                                                                             Might be a little gassy but hey, you go NASA.
# 188                                                                                                                                                                                        Interesting Fact I learned the other day. The space shuttle was the best looking craft to ever fly.
# 265                                                                                                                                                                           Educators - subscribe to NASA Explore newsletter and get a toolkit for bringing the  mission into the classroom.
# 277                                                                  While some of us were celebrating Christmas, the scientists at  were busy launching the  successfully!!!The fine people at NASA have created something to help you follow along as it deploys its many and various parts!
# 283                                                ICYMI: NASA &amp; CDSE member  teams placed the  III  forward skirt on the Michoud Assembly Facility Vertical Assembly Center robotic weld tool for its next production phase. The forward skirt will host flight computers &amp; avionics:
# 294           part 3:  around the spacecraft  and then amplify and distribute said energy to thrusters as the craft begins to gain more and more speed due to an infinite amount of energy needed to reach the speed of light. Nuclear fission being used to do that is too risky i would say.
# 320                                                                                                                                                                                          Then why is there a can spinning in this fake CGI NASA video? Scroll 4mins in.  I’ll wait…. Next.
# 349                                                                                                                                                                                                                             I give up. It looks like a space shuttle, how can that be new?
# 357                                                                                                                                                                                                                                   How does one watch this and believes anything NASA says?
# 394                                                                                              Jump to 9 minutes here and yo see how incredibly stupid it is to believe NASA. Are you serious that you believe this bullshit?:  Answer me one time why they fake things like that. Answer me
# 421    This is not America anymore. Just look at the NASA James Web telescope recently launched with the great majority of funding and novel technology produced by the US government and tax payer. All the mission control is from France and operated entirely by them with little English.
# 432                                                                                           In this dismal time when we’re surrendering to Covid and watching the American experiment in democracy fail, it’s nice to see NASA deliver an historic scientific achievement. That’s something.
# 482                                                                                                                                                                                                                   My nerdy little heart just expanded and burst.  NASA speaking lang belta
# 485                                                                   Poor old Dick. You think that just because its on French territory it's French. No, no, no. Only 1/3rd of it is French, the rest belongs to the European Space Agency. Of which we are a major member. Try harder, Dick.
# 525                                                                                                                                 On our way!55 minutes into its flight, the  spacecraft has separated from the  Falcon 9 second stage, and will soon begin to orient itself toward the Sun.
# 526                                 "It's safe to say that in the next 24 hours it will be down but where, nobody can say, because in the window of several hours it will do several revolutions around the globe." - Holger Krag, the head of the European Space Agency's Space Debris Office
# 555                                                                                                                                                                                                                  Never gets old.Even for a 60 year old that watched the early days of NASA
# 565                                                                                                                                              Thank you, NASA, forIستايليIAh, what happine, getting even IسيفيIDon’t focus on outward means of satisfaction if you  ARAB  JVK كُوُدَ خَصٍمٍ
# 574                                                                                                                                              Thank you, NASA, for keeping watch and realizing that our univers  ◥ ツ كؤد IخُصمI ツ ◤ IنونI"IسيفيIIنمشيIBe happy for what you hav NBF150timer
# 691                              Most likely it is some kind of display that draws on all the info from the various sensors that graphically represents the spacecraft’s status and configuration. No earth-based telescope would have the resolution to see what was happening in any detail.
# 783                                                                                                                                                                                                            NASA is literally building a telescope in space as it heads for its destination
# 801                                                                                                                                                                               Journey is seven months with a  spacecraft 24,600kph (39,600 kph) 300 million miles (480 million kilometres)
# 833                                                                                                                    NASA telescope deploys  array: NASA sent the world’s most powerful telescope into space on Dec. 25. It deployed and powered a related PV array 30 minutes after launch.
# 958                                                                                                                                                                If anyone responds to your tweet with the phrase “tension is building as we await NASA’s briefing,” they should be blocked.
# 1043     Sure, but Arianespace needed a medium size rocket between the Vega and the ariane V. So they entered into an agreement with roscosmos or a subsidiary to market the rocket  internationaly and launch it from french gyana. So in ESA eyes that was launches from a domestic supplier
# 1086                                                                     NASA: We just fixed the engine issue! With that out of the way we think we're gonna be able to roll out the rocket in mid February, only around 2 weeks later than planned. Eric Berger: This is a SIGNIFICANT delay.
# 1145                                                                                                                                             Cameras lead to additional risks, work and where not needed for the functionality of the telescope. NASA isn't an entertainment company mate.
# 1303                                                        NASA One (flight control): "It looks good at NASA One."B-52 Pilot: "Roger. BCS Arm switch is on."NASA One: "Okay, Victor."B-52 Pilot: "Lining Rocket Arm switch is on."B-52 Pilot: "Here comes the throttle. Circuit breakers in."
#
#            subject
# 113   Jwst-mission
# 146   Jwst-mission
# 159   Jwst-mission
# 188     Jwst-facts
# 265   Jwst-mission
# 277   Jwst-mission
# 283   Jwst-mission
# 294     Jwst-facts
# 320   Jwst-mission
# 349     Jwst-facts
# 357   Jwst-mission
# 394   Jwst-mission
# 421     Jwst-facts
# 432     Jwst-facts
# 482   Jwst-mission
# 485   Jwst-mission
# 525   Jwst-mission
# 526   Jwst-mission
# 555   Jwst-mission
# 565   Jwst-mission
# 574   Jwst-mission
# 691     Jwst-facts
# 783   Jwst-mission
# 801     Jwst-facts
# 833   Jwst-mission
# 958   Jwst-mission
# 1043  Jwst-mission
# 1086  Jwst-mission
# 1145  Jwst-mission
# 1303  Jwst-mission

# %% [markdown]
# **Observations**
# 1. The search term list does not capture less than 10% of candidate tweets.
# 2. Some of the leftover tweets are directly related to the current project. However, expanding the search terms list (`wanted_list`) to include terms that would capture these leftover tweets would also result in capturing unrelated tweets. eg. including `NASA` or `nasa` will capture most of these leftover tweets, but will also pick up tweets about other (unrelated) NASA missions that are not relevant for this project.
